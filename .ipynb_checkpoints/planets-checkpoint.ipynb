# %%
# 3D Model Solar System

# %%
# links

# https://nssdc.gsfc.nasa.gov/planetary/factsheet/
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html
# http://hyperphysics.phy-astr.gsu.edu/hbase/Solar/sun.html

# %%
# import existing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import data files
# to use later DataFrame.to_csv
df = pd.read_csv('planet_fact_sheet_NASA.csv')# planet data from NASA | dont want indexing...yet

# %%
# clean up the data frame
df.rename(columns={'Unnamed: 0':'Metrics'},inplace=True) # rename column Unnamed: 0

# %%
# Set the metrics to be the indexing for the data
planet_data = df.set_index('Metrics') # this will prevent an index being reintroduced in inversion

# %%
inverse_planet_data = planet_data.T

# %%
planet_data
# Out:
#                               MERCURY    VENUS  EARTH    MOON   MARS JUPITER  \
# Metrics
# Mass (1024kg)                    0.33     4.87   5.97   0.073  0.642    1898
# Diameter (km)                    4879    12104  12756    3475   6792  142984
# Density (kg/m3)                  5429     5243   5514    3340   3934    1326
# Gravity (m/s2)                    3.7      8.9    9.8     1.6    3.7    23.1
# Escape Velocity (km/s)            4.3     10.4   11.2     2.4      5    59.5
# Rotation Period (hours)        1407.6  -5832.5   23.9   655.7   24.6     9.9
# Length of Day (hours)          4222.6     2802     24   708.7   24.7     9.9
# Distance from Sun (106 km)       57.9    108.2  149.6  0.384*    228   778.5
# Perihelion (106 km)                46    107.5  147.1  0.363*  206.7   740.6
# Aphelion (106 km)                69.8    108.9  152.1  0.406*  249.3   816.4
# Orbital Period (days)              88    224.7  365.2   27.3*    687    4331
# ...

# %%
inverse_planet_data
# Out:
# Metrics Mass (1024kg) Diameter (km) Density (kg/m3) Gravity (m/s2)  \
# MERCURY          0.33          4879            5429            3.7
# VENUS            4.87         12104            5243            8.9
# EARTH            5.97         12756            5514            9.8
# MOON            0.073          3475            3340            1.6
# MARS            0.642          6792            3934            3.7
# JUPITER          1898        142984            1326           23.1
# SATURN            568        120536             687              9
# URANUS           86.8         51118            1270            8.7
# NEPTUNE           102         49528            1638             11
# PLUTO           0.013          2376            1850            0.7
#
# Metrics Escape Velocity (km/s) Rotation Period (hours) Length of Day (hours)  \
# MERCURY                    4.3                  1407.6                4222.6
# ...

# %%
inverse_planet_data.columns
# Out:
# Index(['Mass (1024kg)', 'Diameter (km)', 'Density (kg/m3)', 'Gravity (m/s2)',
#        'Escape Velocity (km/s)', 'Rotation Period (hours)',
#        'Length of Day (hours)', 'Distance from Sun (106 km)',
#        'Perihelion (106 km)', 'Aphelion (106 km)', 'Orbital Period (days)',
#        'Orbital Velocity (km/s)', 'Orbital Inclination (degrees)',
#        'Orbital Eccentricity', 'Obliquity to Orbit (degrees)',
#        'Mean Temperature (C)', 'Surface Pressure (bars)', 'Number of Moons',
#        'Ring System?', 'Global Magnetic Field?'],
#       dtype='object', name='Metrics')

# %%
inverse_planet_data.loc['EARTH']
# Out:
# Metrics
# Mass (1024kg)                     5.97
# Diameter (km)                    12756
# Density (kg/m3)                   5514
# Gravity (m/s2)                     9.8
# Escape Velocity (km/s)            11.2
# Rotation Period (hours)           23.9
# Length of Day (hours)               24
# Distance from Sun (106 km)       149.6
# Perihelion (106 km)              147.1
# Aphelion (106 km)                152.1
# Orbital Period (days)            365.2
# Orbital Velocity (km/s)           29.8
# Orbital Inclination (degrees)        0
# Orbital Eccentricity             0.017
# Obliquity to Orbit (degrees)      23.4
# Mean Temperature (C)                15
# Surface Pressure (bars)              1
# Number of Moons                      1
# Ring System?                        No
# Global Magnetic Field?             Yes
# Name: EARTH, dtype: object

# %%
inverse_planet_data.loc['SUN'] = [1988500, 
                                  1391400, 
                                  1408, 
                                  274, 
                                  617.6, 
                                  609, 
                                  0, 
                                  0,
                                  0,
                                  0,
                                  7.25,
                                  5499,

# %%
695700*2
# Out:
# 1391400
